# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
accidentesVF=pd.read_csv("accidentesNacVF.csv")

# %%
accidentesVF.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'INEGI-EST', 'ESTADO', 'INEGI-MUN',
#        'MUNICIPIO', 'fechaaccidentes', 'feriadopranio', 'Feriadodummy',
#        'Feriadotipo', 'DIAs', 'MESs', 'ANIOs', 'DIASEMANA', 'TIPACCID',
#        'CAUSAACCI', 'SEXO', 'ALIENTO', 'EDAD', 'DummyCausaConductor',
#        'DummyCausaPeatonpasajero', 'DummyCausaFallavehículo',
#        'DummyCausacondiccamino', 'DummyCausaotrascausas', 'CVE_MUN_COMP',
#        'RESTMUN14', 'RESTMUN15', 'RESTMUN16', 'RESTMUN17', 'RESTMUN18',
#        'BARESMUN14', 'BARESMUN15', 'BARESMUN16', 'BARESMUN17', 'BARESMUN18',
#        'SALONESFIESTA14', 'SALONESFIESTA15', 'SALONESFIESTA16',
#        'SALONESFIESTA17', 'SALONESFIESTA18', 'PLAZAS14', 'PLAZAS15',
#        'PLAZAS16', 'PLAZAS17', 'PLAZAS18'],
#       dtype='object')

# %%
accidentesVF.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  INEGI-EST          ESTADO  INEGI-MUN  \
# 0           0             0          1  Aguascalientes          5
# 1           1             1          1  Aguascalientes          5
# 2           2             2          1  Aguascalientes          5
# 3           3             3          1  Aguascalientes          5
# 4           4             4          1  Aguascalientes          5
#
#      MUNICIPIO fechaaccidentes             feriadopranio Feriadodummy  \
# 0  Jesús María        2/1/2014  Vaciones fin de año 2014      Feriado
# 1  Jesús María        3/1/2014  Vaciones fin de año 2014      Feriado
# 2  Jesús María        3/1/2014  Vaciones fin de año 2014      Feriado
# 3  Jesús María        3/1/2014  Vaciones fin de año 2014      Feriado
# 4  Jesús María        5/1/2014  Vaciones fin de año 2014      Feriado
#
#              Feriadotipo  ...  SALONESFIESTA16  SALONESFIESTA17  \
# 0  Vacaciones fin de año  ...               51               52
# ...

# %%
accidentesVF.groupby("DIASEMANA")["DIASEMANA"].count()
# Out:
# DIASEMANA
# 1    257295
# 2    248893
# 3    249559
# 4    252165
# 5    284863
# 6    296459
# 7    261333
# Name: DIASEMANA, dtype: int64

# %%
accidentesVF.groupby("Feriadodummy")["Feriadodummy"].count()
# Out:
# Feriadodummy
# Feriado        120026
# No feriado    1730541
# Name: Feriadodummy, dtype: int64

# %%
from scipy.stats import ttest_ind
from scipy import stats

# %%
from scipy import stats

# %%
grupo_feriados=accidentesVF.groupby(["fechaaccidentes","Feriadodummy"])["Feriadodummy"].count()

# %%
grupo_feriados
# Out:
# fechaaccidentes  Feriadodummy
# 1/1/2014         Feriado         1262
# 1/1/2015         Feriado         1164
# 1/1/2016         Feriado         1285
# 1/1/2017         Feriado         1300
# 1/1/2018         Feriado         1305
# 1/10/2014        No feriado      1158
# 1/10/2015        No feriado      1266
# 1/10/2016        No feriado      1244
# 1/10/2017        No feriado      1251
# 1/10/2018        No feriado      1121
# 1/11/2014        No feriado      1375
# 1/11/2015        No feriado      1304
# 1/11/2016        No feriado      1183
# 1/11/2017        No feriado      1349
# 1/11/2018        No feriado      1178
# 1/12/2014        No feriado      1304
# 1/12/2015        No feriado      1156
# 1/12/2016        No feriado      1341
# 1/12/2017        No feriado      1400
# 1/12/2018        No feriado      1365
# 1/2/2014         No feriado      1410
# 1/2/2015         No feriado      1245
# 1/2/2016         No feriado       973
# 1/2/2017         No feriado      1187
# ...

# %%
Gruposferiados=pd.DataFrame(grupo_feriados)
Gruposferiados
# Out:
#                               Feriadodummy
# fechaaccidentes Feriadodummy
# 1/1/2014        Feriado               1262
# 1/1/2015        Feriado               1164
# 1/1/2016        Feriado               1285
# 1/1/2017        Feriado               1300
# 1/1/2018        Feriado               1305
# 1/10/2014       No feriado            1158
# 1/10/2015       No feriado            1266
# 1/10/2016       No feriado            1244
# 1/10/2017       No feriado            1251
# 1/10/2018       No feriado            1121
# 1/11/2014       No feriado            1375
# 1/11/2015       No feriado            1304
# 1/11/2016       No feriado            1183
# 1/11/2017       No feriado            1349
# 1/11/2018       No feriado            1178
# 1/12/2014       No feriado            1304
# 1/12/2015       No feriado            1156
# 1/12/2016       No feriado            1341
# 1/12/2017       No feriado            1400
# 1/12/2018       No feriado            1365
# ...

# %%
Gruposferiados.to_csv("Gruposferiados.csv")

# %%
Gruposferiados=pd.read_csv("Gruposferiados.csv")

# %%
Gruposferiados
# Out:
#      fechaaccidentes Feriadodummy  Totalportipo
# 0         01/01/2014      Feriado          1262
# 1         01/01/2015      Feriado          1164
# 2         01/01/2016      Feriado          1285
# 3         01/01/2017      Feriado          1300
# 4         01/01/2018      Feriado          1305
# 5         01/10/2014   No feriado          1158
# 6         01/10/2015   No feriado          1266
# 7         01/10/2016   No feriado          1244
# 8         01/10/2017   No feriado          1251
# 9         01/10/2018   No feriado          1121
# 10        01/11/2014   No feriado          1375
# 11        01/11/2015   No feriado          1304
# 12        01/11/2016   No feriado          1183
# 13        01/11/2017   No feriado          1349
# 14        01/11/2018   No feriado          1178
# 15        01/12/2014   No feriado          1304
# 16        01/12/2015   No feriado          1156
# 17        01/12/2016   No feriado          1341
# 18        01/12/2017   No feriado          1400
# ...

# %%
Grupo1Feriado=Gruposferiados[Gruposferiados['Feriadodummy'].str.contains("Feriado")]

# %%
Grupo1Feriado['Totalportipo'].mean()
# Out:
# 909.2878787878788

# %%
Grupo2NoFeriado['Totalportipo'].mean()
# Out:
# 1021.5708382526565

# %%
Grupo2NoFeriado=Gruposferiados[Gruposferiados['Feriadodummy'].str.contains("No feriado")]

# %%
ttest_ind(Grupo1Feriado['Totalportipo'], Grupo2NoFeriado['Totalportipo'],equal_var=False)
# Out:
# Ttest_indResult(statistic=-8.57411968801864, pvalue=1.4816769906623968e-14)

# %%
(t_stat,p)
# Out:
# (-8.57411968801864, 1.4816769906623968e-14)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
plt.subplot(2, 1, 2)
plt.hist(Grupo1Feriado['Totalportipo'], 100, density=True, alpha=0.7, label="Feriados")
plt.hist(Grupo2NoFeriado['Totalportipo'], 100, density=True, alpha=0.7, label="No feriados")
plt.axvline(Grupo1Feriado['Totalportipo'].mean(), color='k', linestyle='dashed', linewidth=2)
plt.axvline(Grupo2NoFeriado['Totalportipo'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.title("Comparativo Feriados vs No Feriados")
plt.savefig("Comparativo Feriados vs No Feriados.pdf")

# %%
grupo_tipoferiados=accidentesVF.groupby(["Feriadotipo"])["Feriadotipo"].count()

# %%
grupo_tipoferiados
# Out:
# Feriadotipo
# Año nuevo                      6316
# Batalla de Puebla              4110
# Dia del trabajo                6076
# Fin de año                     4171
# Fin vacaiones verano           4991
# Independencia de México       10089
# Inicio vacaciones verano       4769
# Navidad                        4472
# No feriado                  1730541
# Nochebuena                     5064
# Semana Santa                  13044
# Vacaciones fin de año         56924
# Name: Feriadotipo, dtype: int64

# %%
Grupostipoferiados=pd.DataFrame(grupo_tipoferiados)
Grupostipoferiados
# Out:
#                           Feriadotipo
# Feriadotipo
# Año nuevo                        6316
# Batalla de Puebla                4110
# Dia del trabajo                  6076
# Fin de año                       4171
# Fin vacaiones verano             4991
# Independencia de México         10089
# Inicio vacaciones verano         4769
# Navidad                          4472
# No feriado                    1730541
# Nochebuena                       5064
# Semana Santa                    13044
# Vacaciones fin de año           56924

# %%
Grupostipoferiados.to_csv("Grupostipoferiados.csv")

# %%
Grupostipoferiados=pd.read_csv("Grupostipoferiados.csv")

# %%
Grupostipoferiados
# Out:
#                  Feriadotipo  Total accidentes
# 0                  Año nuevo              6316
# 1          Batalla de Puebla              4110
# 2            Dia del trabajo              6076
# 3                 Fin de año              4171
# 4       Fin vacaiones verano              4991
# 5    Independencia de México             10089
# 6   Inicio vacaciones verano              4769
# 7                    Navidad              4472
# 8                 Nochebuena              5064
# 9               Semana Santa             13044
# 10     Vacaciones fin de año             56924

# %%
Grupostipoferiados["Total accidentes"].mean()
# Out:
# 10911.454545454546

# %%
Grupostipoferiados["Expected"]=Grupostipoferiados["Total accidentes"].mean()

# %%
Grupostipoferiados
# Out:
#                  Feriadotipo  Total accidentes      Expected
# 0                  Año nuevo              6316  10911.454545
# 1          Batalla de Puebla              4110  10911.454545
# 2            Dia del trabajo              6076  10911.454545
# 3                 Fin de año              4171  10911.454545
# 4       Fin vacaiones verano              4991  10911.454545
# 5    Independencia de México             10089  10911.454545
# 6   Inicio vacaciones verano              4769  10911.454545
# 7                    Navidad              4472  10911.454545
# 8                 Nochebuena              5064  10911.454545
# 9               Semana Santa             13044  10911.454545
# 10     Vacaciones fin de año             56924  10911.454545

# %%
critical_value = stats.chi2.ppf(q = 0.95, df = 10)
critical_value
# Out:
# 18.307038053275146

# %%
stats.chisquare(Grupostipoferiados["Total accidentes"],Grupostipoferiados["Expected"])
# Out:
# Power_divergenceResult(statistic=220595.0338426674, pvalue=0.0)

# %%
tipo_fer=accidentesVF.groupby(["fechaaccidentes","Feriadotipo"])["Feriadotipo"].count()

# %%
tipo_fer.to_csv("tipo_feriado.csv")
# Out:
# C:\Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
Grupostipoferiados=pd.read_csv("tipo_feriado.csv")

# %%
Grupostipoferiados
# Out:
#     fechaaccidentes               Feriadotipo  Totalaccidentes
# 0        01/01/2014                 Año nuevo             1262
# 1        01/01/2015                 Año nuevo             1164
# 2        01/01/2016                 Año nuevo             1285
# 3        01/01/2017                 Año nuevo             1300
# 4        01/01/2018                 Año nuevo             1305
# 5        01/04/2018              Semana Santa             1005
# 6        01/05/2014           Dia del trabajo              907
# 7        01/05/2015           Dia del trabajo             1137
# 8        01/05/2016           Dia del trabajo             1205
# 9        01/05/2017           Dia del trabajo              976
# 10       01/05/2018           Dia del trabajo              878
# 11       13/04/2017              Semana Santa              792
# 12       14/04/2017              Semana Santa              783
# 13       14/07/2015  Inicio vacaciones verano              963
# ...

# %%
Grupostipoferiados.columns
# Out:
# Index(['fechaaccidentes', 'Feriadotipo', 'Totalaccidentes'], dtype='object')

# %%
# Create a boxplot to compare means
from matplotlib.font_manager import FontProperties
fontP = FontProperties()
fontP.set_size('.5')
bxplot=Grupostipoferiados.boxplot('Totalaccidentes', by="Feriadotipo", figsize=(10,10),)
bxplot.legend(prop = fontP,fontsize=2)
plt.xticks(ha = 'right', rotation=45)
plt.savefig("Boxplot tipo de feriado.pdf")
# Out:
# No handles with labels found to put in legend.

# %%
difdiasemana=accidentesVF.groupby(["fechaaccidentes","DIASEMANA"])["DIASEMANA"].count()

# %%
difdiasemana
# Out:
# fechaaccidentes  DIASEMANA
# 1/1/2014         3            1262
# 1/1/2015         4            1164
# 1/1/2016         5            1285
# 1/1/2017         7            1300
# 1/1/2018         1            1305
# 1/10/2014        3            1158
# 1/10/2015        4            1266
# 1/10/2016        6            1244
# 1/10/2017        7            1251
# 1/10/2018        1            1121
# 1/11/2014        6            1375
# 1/11/2015        7            1304
# 1/11/2016        2            1183
# 1/11/2017        3            1349
# 1/11/2018        4            1178
# 1/12/2014        1            1304
# 1/12/2015        2            1156
# 1/12/2016        4            1341
# 1/12/2017        5            1400
# 1/12/2018        6            1365
# 1/2/2014         6            1410
# 1/2/2015         7            1245
# 1/2/2016         1             973
# 1/2/2017         3            1187
# 1/2/2018         4            1122
# 1/3/2014         6            1517
# ...

# %%
difdiasemana.to_csv("difdiasemana.csv")
# Out:
# C:\Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-161-b0ba9457550e> in <module>
# ----> 1 difdiasemana.to_csv("difdiasemana.csv")
#
# ~Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\pandas\core\series.py in to_csv(self, *args, **kwargs)
#    4201                           stacklevel=2)
#    4202             kwargs["header"] = False  # Backwards compatibility.
# -> 4203         return self.to_frame().to_csv(**kwargs)
#    4204
#    4205     @Appender(generic._shared_docs['isna'] % _shared_doc_kwargs)
#
# ...

# %%
difdiasemana=pd.read_csv("difdiasemana.csv")

# %%
difdiasemana
# Out:
#            Fecha  Dia  Total accidentes
# 0     01/01/2014    3              1262
# 1     01/01/2015    4              1164
# 2     01/01/2016    5              1285
# 3     01/01/2017    7              1300
# 4     01/01/2018    1              1305
# 5     01/10/2014    3              1158
# 6     01/10/2015    4              1266
# 7     01/10/2016    6              1244
# 8     01/10/2017    7              1251
# 9     01/10/2018    1              1121
# 10    01/11/2014    6              1375
# 11    01/11/2015    7              1304
# 12    01/11/2016    2              1183
# 13    01/11/2017    3              1349
# 14    01/11/2018    4              1178
# 15    01/12/2014    1              1304
# 16    01/12/2015    2              1156
# 17    01/12/2016    4              1341
# 18    01/12/2017    5              1400
# 19    01/12/2018    6              1365
# 20    01/02/2014    6              1410
# 21    01/02/2015    7              1245
# ...

# %%
from matplotlib.font_manager import FontProperties
fontP = FontProperties()
fontP.set_size('.5')
bxplot=difdiasemana.boxplot('Total accidentes', by="Dia", figsize=(10,10),)
bxplot.legend(prop = fontP,fontsize=2)
plt.xticks(ha = 'right', rotation=45)
plt.savefig("Boxplot dia.pdf")
# Out:
# No handles with labels found to put in legend.

# %%
difdiasemana2=accidentesVF.groupby("DIASEMANA")["DIASEMANA"].count()

# %%
difdiasemana2
# Out:
# DIASEMANA
# 1    257295
# 2    248893
# 3    249559
# 4    252165
# 5    284863
# 6    296459
# 7    261333
# Name: DIASEMANA, dtype: int64

# %%
difdiasemana2.to_csv("difdiasemana2.csv")
# Out:
# C:\Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
difdiasemana2=pd.read_csv("difdiasemana2.csv")

# %%
difdiasemana2
# Out:
#    Diasemana  Total accidentes
# 0          1            257295
# 1          2            248893
# 2          3            249559
# 3          4            252165
# 4          5            284863
# 5          6            296459
# 6          7            261333

# %%
difdiasemana2["Expected"]=difdiasemana2["Total accidentes"].mean()

# %%
difdiasemana2
# Out:
#    Diasemana  Total accidentes       Expected
# 0          1            257295  264366.714286
# 1          2            248893  264366.714286
# 2          3            249559  264366.714286
# 3          4            252165  264366.714286
# 4          5            284863  264366.714286
# 5          6            296459  264366.714286
# 6          7            261333  264366.714286

# %%
critical_value = stats.chi2.ppf(q = 0.95, df = 6)
critical_value
# Out:
# 12.591587243743977

# %%
stats.chisquare(difdiasemana2["Total accidentes"],difdiasemana2["Expected"])
# Out:
# Power_divergenceResult(statistic=8007.101685051122, pvalue=0.0)

# %%
accidentesVF.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'INEGI-EST', 'ESTADO', 'INEGI-MUN',
#        'MUNICIPIO', 'fechaaccidentes', 'feriadopranio', 'Feriadodummy',
#        'Feriadotipo', 'DIAs', 'MESs', 'ANIOs', 'DIASEMANA', 'TIPACCID',
#        'CAUSAACCI', 'SEXO', 'ALIENTO', 'EDAD', 'DummyCausaConductor',
#        'DummyCausaPeatonpasajero', 'DummyCausaFallavehículo',
#        'DummyCausacondiccamino', 'DummyCausaotrascausas', 'CVE_MUN_COMP',
#        'RESTMUN14', 'RESTMUN15', 'RESTMUN16', 'RESTMUN17', 'RESTMUN18',
#        'BARESMUN14', 'BARESMUN15', 'BARESMUN16', 'BARESMUN17', 'BARESMUN18',
#        'SALONESFIESTA14', 'SALONESFIESTA15', 'SALONESFIESTA16',
#        'SALONESFIESTA17', 'SALONESFIESTA18', 'PLAZAS14', 'PLAZAS15',
#        'PLAZAS16', 'PLAZAS17', 'PLAZAS18'],
#       dtype='object')

# %%
accidentesVF['SEXO'].value_counts()
# Out:
# 2    1376858
# 3     270706
# 1     203003
# Name: SEXO, dtype: int64

# %%
sexodummydummy = []
for row in accidentesVF['SEXO']:
    if row =="2":
        sexodummydummy.append('0')
    if row =="3":
        sexodummydummy.append('1')
    else:
        sexodummydummy.append('na')

# %%
accidentesVF['dummysexo']=sexodummy

# %%
accidentesVF['ALIENTO'].value_counts()
# Out:
# 5    1191801
# 6     561957
# 4      96809
# Name: ALIENTO, dtype: int64

# %%
alientoalcoholdummy = []
for row in accidentesVF['ALIENTO']:
    if row =="4":
        alientoalcoholdummy.append('1')
    if row =="5":
        alientoalcoholdummy.append('0')
    else:
        alientoalcoholdummy.append('na')

# %%
accidentesVF['alcoholdummy']=alientoalcoholdummy

# %%
accidentesVF.count()
# Out:
# Unnamed: 0                  1850567
# Unnamed: 0.1                1850567
# INEGI-EST                   1850567
# ESTADO                      1850567
# INEGI-MUN                   1850567
# MUNICIPIO                   1850567
# fechaaccidentes             1850567
# feriadopranio               1850567
# Feriadodummy                1850567
# Feriadotipo                 1850567
# DIAs                        1850567
# MESs                        1850567
# ANIOs                       1850567
# DIASEMANA                   1850567
# TIPACCID                    1850567
# CAUSAACCI                   1850567
# SEXO                        1850567
# ALIENTO                     1850567
# EDAD                        1850567
# DummyCausaConductor         1850567
# DummyCausaPeatonpasajero    1850567
# DummyCausaFallavehículo     1850567
# DummyCausacondiccamino      1850567
# DummyCausaotrascausas       1850567
# CVE_MUN_COMP                1850567
# RESTMUN14                   1850567
# ...

# %%
Accidentmun=accidentesVF.groupby(["CVE_MUN_COMP","fechaaccidentes"])["fechaaccidentes"].count()

# %%
#VARIABLE DEPENDIENTE ACCIDENTES POR MUNICIPIO Y FECHA
Accidentmun
# Out:
# CVE_MUN_COMP  fechaaccidentes
# 1001          1/1/2014            9
#               1/1/2015           12
#               1/1/2016           16
#               1/1/2017           17
#               1/1/2018           14
#               1/10/2014          12
#               1/10/2015           7
#               1/10/2016           9
#               1/10/2017           7
#               1/10/2018           9
#               1/11/2014          13
#               1/11/2015          12
#               1/11/2016           7
#               1/11/2017           9
#               1/11/2018           9
#               1/12/2014           8
#               1/12/2015           8
#               1/12/2016           3
#               1/12/2017          13
#               1/12/2018          14
#               1/2/2014            7
#               1/2/2015           11
#               1/2/2016            5
#               1/2/2017           11
#               1/2/2018            7
# ...

# %%
Edprom=accidentesVF.groupby(["CVE_MUN_COMP","fechaaccidentes"])['EDAD'].mean()

# %%
Edprom
# Out:
# CVE_MUN_COMP  fechaaccidentes
# 1001          1/1/2014           44.222222
#               1/1/2015           25.250000
#               1/1/2016           34.500000
#               1/1/2017           29.411765
#               1/1/2018           34.000000
#               1/10/2014          35.916667
#               1/10/2015          26.285714
#               1/10/2016          30.000000
#               1/10/2017          34.000000
#               1/10/2018          36.444444
#               1/11/2014          26.230769
#               1/11/2015          26.750000
#               1/11/2016          33.428571
#               1/11/2017          31.555556
#               1/11/2018          34.666667
#               1/12/2014          33.375000
#               1/12/2015          28.500000
#               1/12/2016          31.666667
#               1/12/2017          32.153846
#               1/12/2018          30.928571
#               1/2/2014           19.857143
# ...

# %%
accidentesVF.dtypes
# Out:
# Unnamed: 0                   int64
# Unnamed: 0.1                 int64
# INEGI-EST                    int64
# ESTADO                      object
# INEGI-MUN                    int64
# MUNICIPIO                   object
# fechaaccidentes             object
# feriadopranio               object
# Feriadodummy                object
# Feriadotipo                 object
# DIAs                         int64
# MESs                         int64
# ANIOs                        int64
# DIASEMANA                    int64
# TIPACCID                     int64
# CAUSAACCI                    int64
# SEXO                         int64
# ALIENTO                      int64
# EDAD                         int64
# DummyCausaConductor          int64
# DummyCausaPeatonpasajero     int64
# DummyCausaFallavehículo      int64
# DummyCausacondiccamino       int64
# DummyCausaotrascausas        int64
# CVE_MUN_COMP                 int64
# RESTMUN14                    int64
# RESTMUN15                    int64
# ...

# %%
accidentesVF["SEXO"].value_counts()
# Out:
# 2    1376858
# 3     270706
# 1     203003
# Name: SEXO, dtype: int64

# %%
accidentesVF["SEXO"].count()
# Out:
# 1850567

# %%
accidentesVF["SEXO"]=accidentesVF["SEXO"].astype("int64")

# %%
sexovf=[]
for row in accidentesVF["SEXO"]:
    if row ==2:
        sexovf.append(0)
    if row ==3:
        sexovf.append(1)
    if row ==1:
        sexovf.append(0)
    else:
        sexovf.append("no clasificado")

# %%
len(sexovf)
# Out:
# 3498131

# %%
################################3
Sexo=accidentesVF.groupby(['CVE_MUN_COMP',"fechaaccidentes"])['DUMMYSEX'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-262-5bf6a23af465> in <module>
#       1 ################################3
# ----> 2 Sexo=accidentesVF.groupby(['CVE_MUN_COMP',"fechaaccidentes"])['DUMMYSEX'].mean()
#
# ~Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     836
#     837         if len(output) == 0:
# --> 838             raise DataError('No numeric types to aggregate')
#     839
# ...

# %%
alientoalcohol=accidentesVF.groupby('MUNICIPIO')['alcoholdummy'].sum()

# %%
restaurantes=accidentesVF.groupby('MUNICIPIO')['RESTMUN16'].unique()

# %%
restaurantes
# Out:
# MUNICIPIO
# Abasolo                                                 [2]
# Acacoyagua                                             [75]
# Acala                                                  [94]
# Acambay de Ruíz Castañeda                              [71]
# Acanceh                                                [65]
# Acapetahua                                             [97]
# Acaponeta                                             [163]
# Acapulco de Juárez                                   [4046]
# Acateno                                                [36]
# Acatepec                                               [19]
# Acatic                                                 [69]
# Acatlán                                        [208, 7, 18]
# Acatlán de Juárez                                     [114]
# Acatlán de Pérez Figueroa                             [148]
# Acatzingo                                             [121]
# ...

# %%
accidentesVF["BARESMUN16"]=accidentesVF["BARESMUN16"].astype("int64")

# %%
bares=accidentesVF.groupby(["CVE_MUN_COMP","fechaaccidentes"])['BARESMUN16'].unique()

# %%
bares
# Out:
# CVE_MUN_COMP  fechaaccidentes
# 1001          1/1/2014           [214]
#               1/1/2015           [214]
#               1/1/2016           [214]
#               1/1/2017           [214]
#               1/1/2018           [214]
#               1/10/2014          [214]
#               1/10/2015          [214]
#               1/10/2016          [214]
#               1/10/2017          [214]
#               1/10/2018          [214]
#               1/11/2014          [214]
#               1/11/2015          [214]
#               1/11/2016          [214]
#               1/11/2017          [214]
#               1/11/2018          [214]
#               1/12/2014          [214]
#               1/12/2015          [214]
#               1/12/2016          [214]
#               1/12/2017          [214]
#               1/12/2018          [214]
#               1/2/2014           [214]
#               1/2/2015           [214]
#               1/2/2016           [214]
# ...

# %%
accidentesVF["PLAZAS16"]=accidentesVF["PLAZAS16"].astype("int64")

# %%
plazas=accidentesVF.groupby(["CVE_MUN_COMP","fechaaccidentes"])['PLAZAS16'].unique()

# %%
plazas
# Out:
# CVE_MUN_COMP  fechaaccidentes
# 1001          1/1/2014           [22]
#               1/1/2015           [22]
#               1/1/2016           [22]
#               1/1/2017           [22]
#               1/1/2018           [22]
#               1/10/2014          [22]
#               1/10/2015          [22]
#               1/10/2016          [22]
#               1/10/2017          [22]
#               1/10/2018          [22]
#               1/11/2014          [22]
#               1/11/2015          [22]
#               1/11/2016          [22]
#               1/11/2017          [22]
#               1/11/2018          [22]
#               1/12/2014          [22]
#               1/12/2015          [22]
#               1/12/2016          [22]
#               1/12/2017          [22]
#               1/12/2018          [22]
#               1/2/2014           [22]
#               1/2/2015           [22]
#               1/2/2016           [22]
#               1/2/2017           [22]
# ...

# %%
accidentesVF["SALONESFIESTA16"]=accidentesVF["SALONESFIESTA16"].astype("int64")

# %%
salones=accidentesVF.groupby(["CVE_MUN_COMP","fechaaccidentes"])['SALONESFIESTA16'].unique()

# %%
accidentesVF["RESTMUN16"]=accidentesVF["RESTMUN16"].astype("int64")

# %%
restaurantes=accidentesVF.groupby(["CVE_MUN_COMP","fechaaccidentes"])['RESTMUN16'].unique()

# %%
datafreg={"Totalmun":Accidentmun,
         "Edad":Edprom,
         "Restaurantes":restaurantes,
         "bares":bares,
         "plazas":plazas,
         "salones":salones}

# %%
datafreg=pd.DataFrame(datafreg)
datafreg
# Out:
#                               Totalmun       Edad Restaurantes  bares plazas  \
# CVE_MUN_COMP fechaaccidentes
# 1001         1/1/2014                9  44.222222       [4101]  [214]   [22]
#              1/1/2015               12  25.250000       [4101]  [214]   [22]
#              1/1/2016               16  34.500000       [4101]  [214]   [22]
#              1/1/2017               17  29.411765       [4101]  [214]   [22]
#              1/1/2018               14  34.000000       [4101]  [214]   [22]
#              1/10/2014              12  35.916667       [4101]  [214]   [22]
#              1/10/2015               7  26.285714       [4101]  [214]   [22]
#              1/10/2016               9  30.000000       [4101]  [214]   [22]
#              1/10/2017               7  34.000000       [4101]  [214]   [22]
#              1/10/2018               9  36.444444       [4101]  [214]   [22]
#              1/11/2014              13  26.230769       [4101]  [214]   [22]
# ...

# %%
datafreg.dtypes
# Out:
# Totalmun          int64
# Edad            float64
# Restaurantes     object
# bares            object
# plazas           object
# salones          object
# dtype: object

# %%
datafreg["Totalmun"]=datafreg["Totalmun"].astype("double")
datafreg["Edad"]=datafreg["Edad"].astype("double")
datafreg["Restaurantes"]=datafreg["Restaurantes"].astype("double")
datafreg["bares"]=datafreg["bares"].astype("double")
datafreg["plazas"]=datafreg["plazas"].astype("double")
datafreg["salones"]=datafreg["salones"].astype("double")

# %%
datafreg["Edad2"]=datafreg["Edad"]*datafreg["Edad"]

# %%
datafreg.dtypes
# Out:
# Totalmun        float64
# Edad            float64
# Restaurantes    float64
# bares           float64
# plazas          float64
# salones         float64
# Edad2           float64
# dtype: object

# %%
datafreg
# Out:
#                               Totalmun       Edad  Restaurantes  bares  \
# CVE_MUN_COMP fechaaccidentes
# 1001         1/1/2014              9.0  44.222222        4101.0  214.0
#              1/1/2015             12.0  25.250000        4101.0  214.0
#              1/1/2016             16.0  34.500000        4101.0  214.0
#              1/1/2017             17.0  29.411765        4101.0  214.0
#              1/1/2018             14.0  34.000000        4101.0  214.0
#              1/10/2014            12.0  35.916667        4101.0  214.0
#              1/10/2015             7.0  26.285714        4101.0  214.0
#              1/10/2016             9.0  30.000000        4101.0  214.0
#              1/10/2017             7.0  34.000000        4101.0  214.0
#              1/10/2018             9.0  36.444444        4101.0  214.0
#              1/11/2014            13.0  26.230769        4101.0  214.0
#              1/11/2015            12.0  26.750000        4101.0  214.0
# ...

# %%
from sklearn import linear_model

# %%
Y=datafreg["Totalmun"]
X=datafreg[["Edad","Edad2","Restaurantes","bares","plazas","salones"]]
regr= linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
#print(regr.summary_)
# Out:
# Intercept:
#  -0.5028866129808276
# Coefficients:
#  [ 0.05362096 -0.00057352 -0.00262978  0.02900891  0.56662885  0.00680037]

# %%
import statsmodels.api as sm
Y=datafreg["Totalmun"]
X=datafreg[["Edad","Edad2","Restaurantes","bares","plazas","salones"]]
X2 = sm.add_constant(X)
est = sm.OLS(Y,X2)
est2 = est.fit()
print(est2.summary())
#regr= linear_model.LinearRegression()
#regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
#print(regr.summary_)
# Out:
# C:\Users\JESICA\Anaconda3.5\envs\gdal_env\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                             OLS Regression Results
# ...
# Dep. Variable:               Totalmun   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                 5.188e+04
# Date:                Sat, 20 Jul 2019   Prob (F-statistic):               0.00
# Time:                        01:34:11   Log-Likelihood:            -1.5260e+06
# No. Observations:              473050   AIC:                         3.052e+06
# Df Residuals:                  473043   BIC:                         3.052e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ...

# %%
#Scatter Accidentes vs Edad2
Y=datafreg["Totalmun"]
X=datafreg["Edad2"]
colors = (0,0,0)
plt.scatter(X, Y,  c=colors, alpha=0.5)
plt.title('Accidentes vs Edad2')
plt.xlabel('Edad')
plt.ylabel('Accidentes')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Scatter Accidentes vs Edad2
X=datafreg["Totalmun"]
Y=datafreg["Edad2"]
colors = (0,0,0)
plt.scatter(X, Y,  c=colors, alpha=0.5)
plt.title('Accidentes vs Edad2')
plt.xlabel('Accidentes')
plt.ylabel('Edad')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Scatter Accidentes vs Bares
Y=datafreg["Totalmun"]
X=datafreg["bares"]
colors = (0,0,0)
plt.scatter(X, Y,  c=colors, alpha=0.5)
plt.title('Accidentes vs Bares')
plt.xlabel('Bares')
plt.ylabel('Accidentes')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Scatter Accidentes vs Bares
Y=datafreg["Totalmun"]
X=datafreg["plazas"]
colors = (0,0,0)
plt.scatter(X, Y,  c=colors, alpha=0.5)
plt.title('Accidentes vs plazas')
plt.xlabel('Plazas')
plt.ylabel('Accidentes')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
